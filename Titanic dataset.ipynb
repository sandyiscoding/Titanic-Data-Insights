# %% [markdown]
# # **Titanic Dataset Analysis**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Data Science/Python/Data source/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Data Frame Analysis (Understanding the data)**

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Pasaenger ID is a irrelevant column so we can drop it.

# %%
df = df.drop(columns='PassengerId')

# %% [markdown]
# df

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df[['Parch','Pclass','Age','SibSp','Fare','Survived']].apply(pd.unique)
# Out:
# Parch                                   [0, 1, 2, 5, 3, 4, 6]
# Pclass                                              [3, 1, 2]
# Age         [22.0, 38.0, 26.0, 35.0, nan, 54.0, 2.0, 27.0,...
# SibSp                                   [1, 0, 3, 4, 2, 5, 8]
# Fare        [7.25, 71.2833, 7.925, 53.1, 8.05, 8.4583, 51....
# Survived                                               [0, 1]
# dtype: object

# %% [markdown]
# # **Some Graphs, visualization**

# %% [markdown]
# # To find the outlier

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Fare distribution by Class')
plt.show()

# %%
sns.boxplot(x='Embarked', y='Fare', data=df)
plt.title('Fare distribution by Embarkation Port')
plt.show()

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'Fare'}>],
#        [<Axes: title={'center': 'Family'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# Task 1: How many survived classwise? Display percentage.

# %%
df_pclass_survival = df[['Pclass','Survived']].groupby(['Pclass']).mean().reset_index()
df_pclass_survival[['Survived']]=df_pclass_survival[['Survived']]*100
df_pclass_survival.rename(columns={'Survived':'Survival in %'},inplace=True)

# %%
sns.barplot(x='Pclass',y='Survival in %',data=df_pclass_survival)
plt.show()

# %% [markdown]
# Task 2: How many survived Genderwise? Display percentage.

# %%
df_gender_survival = df[['Sex','Survived']].groupby('Sex').mean().reset_index()
df_gender_survival[['Survived']]=df_gender_survival[['Survived']]*100
df_gender_survival.rename(columns={'Survived':'Survival in %'},inplace=True)

# %%
sns.barplot(x='Sex',y='Survival in %',data=df_gender_survival)
plt.show()

# %% [markdown]
# Task 3: Extract the salutation of each person and give the count

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.')

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer'], dtype=object)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
def replace_title(row):
  title = row['Title']
  relevant_titles = ['Mr', 'Mrs', 'Miss', 'Master']
  if title in relevant_titles:
    return title
  else:
    return "Others"

# %%
df['Title'] = df.apply(replace_title, axis=1)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Others'], dtype=object)

# %% [markdown]
# Task 4: Find our the average age of Mr., Mrs, Miss and Master.

# %%
df.groupby('Title')['Age'].mean()
# Out:
# Title
# Master     4.574167
# Miss      21.773973
# Mr        32.368090
# Mrs       35.898148
# Others    42.384615
# Name: Age, dtype: float64

# %% [markdown]
# Task 5: Plot a bar plot. How many survived titlewise?

# %%
#Visual Analysis
import seaborn as sns
sns.countplot(data=df[df['Survived']==1], x='Title')
plt.title('Survival rate by title')
plt.ylabel('Number of survivors')
plt.show()

# %%
sns.barplot(x='Title', y=df['Survived']==1, data=df)
plt.title('Survival rate by title')
plt.show()

# %%
pd.crosstab(df['Title'],df['Sex'])
# Out:
# Sex     female  male
# Title
# Master       0    40
# Miss       182     0
# Mr           0   517
# Mrs        125     0
# Others       7    20

# %%
sns.countplot(x='Survived', hue='Title', data=df, order=[1,0])
plt.xticks(range(2), ['Survived', 'Not Survived'])
plt.show()

# %% [markdown]
# Task 6: Find out relevant columna and then how many members are there in the family and plot a graph of which category of family survived most.

# %%
df['Family'] = df['SibSp'] + df['Parch']
df['Family'].value_counts()
# Out:
# Family
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: count, dtype: int64

# %%
sns.barplot(data=df[['Family', 'Survived']].groupby('Family').mean().reset_index(), x='Family', y='Survived')
plt.show()

# %% [markdown]
# Task 7: Age imputation.

# %%
df[['Sex','Title','Age']].groupby(['Sex','Title']).mean().reset_index()
# Out:
#       Sex   Title        Age
# 0  female    Miss  21.773973
# 1  female     Mrs  35.898148
# 2  female  Others  32.857143
# 3    male  Master   4.574167
# 4    male      Mr  32.368090
# 5    male  Others  45.894737
